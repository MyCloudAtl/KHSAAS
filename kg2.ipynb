# %%
import rdflib
import pandas as pd
import urllib.parse

# %%
pd.set_option('display.max_colwidth', None)

# %%
# Create a new graph
g = rdflib.Graph()

# Load your Turtle file
ttl_file = 'ontology.ttl'  # Change this to the path of your Turtle file
g.parse(ttl_file, format='ttl')
g.parse("secure-chain.ttl", format="ttl")

print(f"Graph has {len(g)} statements.")
# Out:
# Graph has 3887639 statements.

# %%
# Extract unique subjects that are URIs
subjects = set()

for s in g.subjects():
    if isinstance(s, rdflib.URIRef):
        subjects.add(s)

print(f"Found {len(subjects)} unique subjects.")

# Create DataFrame
df = pd.DataFrame(list(subjects), columns=['subject'])

# Function to extract product and version
def extract_product_version(uri):
    uri_str = urllib.parse.unquote(str(uri))
    last_part = uri_str.split('/')[-1]
    if '#' in last_part:
        product, version = last_part.split('#', 1)
    else:
        product = last_part
        version = None
    return product, version

# Apply function to extract product and version
df[['product', 'version']] = df['subject'].apply(lambda x: pd.Series(extract_product_version(x)))
# Out:
# Found 687548 unique subjects.

# %%
# Drop rows with missing product or version
df1 = df.dropna(subset=['product', 'version'])

# Inspect the DataFrame
#print(df.head())

# Export to CSV
df1.to_csv('products_versions.csv', index=False)

# %%
ddf_o = df[df['product'] == 'python']

# %%
ddf_o
# Out:
#                                                   subject product  \
# 1630    https://w3id.org/secure-chain/SoftwareVersion/...  python
# 3715    https://w3id.org/secure-chain/SoftwareVersion/...  python
# 16779   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 17297   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 35291   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 49759   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 67471   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 83912   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 94574   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 95202   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 96324   https://w3id.org/secure-chain/SoftwareVersion/...  python
# 118933  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 128466  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 139260  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 155738  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 159430  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 164853  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 173022  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 181473  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 221587  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 222008  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 227169  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 255183  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 274083  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 275307  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 284067  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 316087      https://w3id.org/secure-chain/Software/python  python
# 321371  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 332520  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 352035  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 359789  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 385401  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 386663  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 395469  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 410923  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 424266  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 427131  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 468960  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 487711  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 498898  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 501148  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 513489  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 516136  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 516229  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 518175  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 529225  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 529339             https://schema.org/Organization/python  python
# 574984  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 607807  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 617781  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 622612  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 627727  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 632169  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 636012  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 644026  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 652421  https://w3id.org/secure-chain/SoftwareVersion/...  python
# 668303  https://w3id.org/secure-chain/SoftwareVersion/...  python
#
#                             version
# 1630                           3.10
# 3715                  <<+2.5&>=+2.3
# 16779                          3.12
# 17297            >=+2.6.6-7~&<<+3.0
# 35291                <<+2.8&>=+2.7~
# 49759                        <<+3.0
# 67471                      >=+2.1.1
# 83912                   >=+2.6.6-3~
# 94574                 <<+2.6&>=+2.5
# 95202                          =2.5
# 96324                           3.4
# 118933                          3.5
# 128466                         =2.4
# 139260                   >=+2.6.6-3
# 155738                       >=+2.7
# 159430                       >=+2.6
# 164853                <<+2.7&>=+2.5
# 173022           >=+2.6.6-7~&<<+2.8
# 181473     >=+2.7.1-0ubuntu2&<<+3.0
# 221587                       >=+2.4
# 222008                  >=+2.6.6-7~
# 227169                          3.9
# 255183                >=+2.7&<<+2.8
# 274083           <<+2.8&>=+2.6.6-7~
# 275307                       >=+2.2
# 284067                          3.7
# 316087                         None
# 321371                <<+2.5&>=+2.4
# 332520                >>+2.6&<<+2.7
# 352035               >=+2.7~&<<+2.8
# 359789  >=+2.6.6-3+squeeze3~&<<+2.7
# 385401                       >=+2.5
# 386663                >=+2.6&<<+2.8
# 395469                          3.8
# 410923                         =2.7
# 424266                <<+2.6&>=+2.4
# 427131                       >=+2.3
# 468960                            3
# 487711                  >=+2.3&<<+3
# 498898                >=+2.4&>=+2.5
# 501148         >=+2.6.6-3+squeeze3~
# 513489                >=+2.5&<<+2.7
# 516136                >=+2.4&<<+2.6
# 516229        <<+2.8&>=+2.7&>=+2.7~
# 518175            >=+2.7.1-0ubuntu2
# 529225                            *
# 529339                         None
# 574984                <<+2.7&>=+2.6
# 607807                    =2.6.6-3~
# 617781                >=+2.3&<<+2.4
# 622612                >=+2.1&<<+2.2
# 627727                          3.6
# 632169                       <<+2.5
# 636012                >=+2.5&<<+2.6
# 644026     >=+2.7.1-0ubuntu2&<<+2.8
# 652421                <<+2.8&>=+2.7
# 668303                <<+2.8&>=+2.6

# %%
list(ddf_o['version'].unique())
# Out:
# ['3.10',
#  '<<+2.5&>=+2.3',
#  '3.12',
#  '>=+2.6.6-7~&<<+3.0',
#  '<<+2.8&>=+2.7~',
#  '<<+3.0',
#  '>=+2.1.1',
#  '>=+2.6.6-3~',
#  '<<+2.6&>=+2.5',
#  '=2.5',
#  '3.4',
#  '3.5',
#  '=2.4',
#  '>=+2.6.6-3',
#  '>=+2.7',
#  '>=+2.6',
#  '<<+2.7&>=+2.5',
#  '>=+2.6.6-7~&<<+2.8',
#  '>=+2.7.1-0ubuntu2&<<+3.0',
#  '>=+2.4',
#  '>=+2.6.6-7~',
#  '3.9',
#  '>=+2.7&<<+2.8',
#  '<<+2.8&>=+2.6.6-7~',
#  '>=+2.2',
#  '3.7',
#  None,
#  '<<+2.5&>=+2.4',
#  '>>+2.6&<<+2.7',
#  '>=+2.7~&<<+2.8',
#  '>=+2.6.6-3+squeeze3~&<<+2.7',
#  '>=+2.5',
#  '>=+2.6&<<+2.8',
#  '3.8',
#  '=2.7',
#  '<<+2.6&>=+2.4',
#  '>=+2.3',
#  '3',
#  '>=+2.3&<<+3',
#  '>=+2.4&>=+2.5',
#  '>=+2.6.6-3+squeeze3~',
#  '>=+2.5&<<+2.7',
#  '>=+2.4&<<+2.6',
#  '<<+2.8&>=+2.7&>=+2.7~',
#  '>=+2.7.1-0ubuntu2',
#  '*',
#  '<<+2.7&>=+2.6',
#  '=2.6.6-3~',
#  '>=+2.3&<<+2.4',
#  '>=+2.1&<<+2.2',
#  '3.6',
#  '<<+2.5',
#  '>=+2.5&<<+2.6',
#  '>=+2.7.1-0ubuntu2&<<+2.8',
#  '<<+2.8&>=+2.7',
#  '<<+2.8&>=+2.6']

# %%
df2 = df1[['product', 'version']].groupby('product').count().reset_index().sort_values('version', ascending=False)
df2
# Out:
#                     product  version
# 3646             ClickHouse     3435
# 63059  platform_system_core     2233
# 51063             llama.cpp     2105
# 7718            aws-sdk-cpp     1930
# 3744             FarManager     1686
# ...                     ...      ...
# 33480          jetwave_4510        1
# 33479      jetwave_4221hp-e        1
# 33478       jetwave_3420_v3        1
# 33476       jetwave_3220_v3        1
# 46074       libnunit2.5-cil        1
#
# [92149 rows x 2 columns]

# %%
df[['property_type', 'software_version']] = df['subject'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)

df
# Out:
#                                                                                         subject  \
# 0                                     https://w3id.org/secure-chain/Vulnerability/CVE-2007-4620
# 1                                    https://w3id.org/secure-chain/Vulnerability/CVE-2021-41145
# 2                                    https://w3id.org/secure-chain/Vulnerability/CVE-2023-39211
# 3                             https://w3id.org/secure-chain/SoftwareVersion/octave#%3E%3D+3.8.1
# 4       https://w3id.org/secure-chain/SoftwareVersion/goldendict#1.5.0~rc2%2Bgit20200409%2Bds-2
# ...                                                                                         ...
# 687543                               https://w3id.org/secure-chain/Vulnerability/CVE-2018-12387
# 687544                                                 https://schema.org/Organization/acrolinx
# 687545                                https://w3id.org/secure-chain/Vulnerability/CVE-2017-4961
# 687546                               https://w3id.org/secure-chain/Vulnerability/CVE-2023-37285
# 687547                                https://w3id.org/secure-chain/Vulnerability/CVE-2023-4442
#
#                product                     version    property_type  \
# 0        CVE-2007-4620                        None    Vulnerability
# 1       CVE-2021-41145                        None    Vulnerability
# 2       CVE-2023-39211                        None    Vulnerability
# 3               octave                    >=+3.8.1  SoftwareVersion
# 4           goldendict  1.5.0~rc2+git20200409+ds-2  SoftwareVersion
# ...                ...                         ...              ...
# 687543  CVE-2018-12387                        None    Vulnerability
# 687544        acrolinx                        None     Organization
# 687545   CVE-2017-4961                        None    Vulnerability
# 687546  CVE-2023-37285                        None    Vulnerability
# 687547   CVE-2023-4442                        None    Vulnerability
#
#                                  software_version
# 0                                   CVE-2007-4620
# 1                                  CVE-2021-41145
# 2                                  CVE-2023-39211
# 3                             octave#%3E%3D+3.8.1
# 4       goldendict#1.5.0~rc2%2Bgit20200409%2Bds-2
# ...                                           ...
# 687543                             CVE-2018-12387
# 687544                                   acrolinx
# 687545                              CVE-2017-4961
# 687546                             CVE-2023-37285
# 687547                              CVE-2023-4442
#
# [687548 rows x 5 columns]

# %%
df['property_type'].unique()
# Out:
# array(['Vulnerability', 'SoftwareVersion', 'Hardware', 'Software',
#        'HardwareVersion', 'Organization', 'Person', 'VulnerabilityType',
#        'secure-chain', 'schema.org', 'widoco', 'License', '1.1', 'vann',
#        'terms', '2001', 'vocommons', 'w3id.org'], dtype=object)

# %%
props = ['Vulnerability', 'SoftwareVersion', 'Hardware', 'Software',
       'HardwareVersion', 'VulnerabilityType']

props
# Out:
# ['Vulnerability',
#  'SoftwareVersion',
#  'Hardware',
#  'Software',
#  'HardwareVersion',
#  'VulnerabilityType']

# %%
df_props = df[df['property_type'].isin(props)]

df_props.to_csv('products_versions2.csv', index=False)

# %%
df_props
# Out:
#                                                                                         subject  \
# 0                                     https://w3id.org/secure-chain/Vulnerability/CVE-2007-4620
# 1                                    https://w3id.org/secure-chain/Vulnerability/CVE-2021-41145
# 2                                    https://w3id.org/secure-chain/Vulnerability/CVE-2023-39211
# 3                             https://w3id.org/secure-chain/SoftwareVersion/octave#%3E%3D+3.8.1
# 4       https://w3id.org/secure-chain/SoftwareVersion/goldendict#1.5.0~rc2%2Bgit20200409%2Bds-2
# ...                                                                                         ...
# 687541                     https://w3id.org/secure-chain/HardwareVersion/business_350-48xt-4x#-
# 687543                               https://w3id.org/secure-chain/Vulnerability/CVE-2018-12387
# 687545                                https://w3id.org/secure-chain/Vulnerability/CVE-2017-4961
# 687546                               https://w3id.org/secure-chain/Vulnerability/CVE-2023-37285
# 687547                                https://w3id.org/secure-chain/Vulnerability/CVE-2023-4442
#
#                      product                     version    property_type  \
# 0              CVE-2007-4620                        None    Vulnerability
# 1             CVE-2021-41145                        None    Vulnerability
# 2             CVE-2023-39211                        None    Vulnerability
# 3                     octave                    >=+3.8.1  SoftwareVersion
# 4                 goldendict  1.5.0~rc2+git20200409+ds-2  SoftwareVersion
# ...                      ...                         ...              ...
# 687541  business_350-48xt-4x                           -  HardwareVersion
# 687543        CVE-2018-12387                        None    Vulnerability
# 687545         CVE-2017-4961                        None    Vulnerability
# 687546        CVE-2023-37285                        None    Vulnerability
# 687547         CVE-2023-4442                        None    Vulnerability
#
#                                  software_version
# 0                                   CVE-2007-4620
# 1                                  CVE-2021-41145
# 2                                  CVE-2023-39211
# 3                             octave#%3E%3D+3.8.1
# 4       goldendict#1.5.0~rc2%2Bgit20200409%2Bds-2
# ...                                           ...
# 687541                     business_350-48xt-4x#-
# 687543                             CVE-2018-12387
# 687545                              CVE-2017-4961
# 687546                             CVE-2023-37285
# 687547                              CVE-2023-4442
#
# [634158 rows x 5 columns]

# %%
df_props[['product', 'version']].groupby('product').count().reset_index().sort_values('version', ascending=False)
# Out:
#                      product  version
# 263461            ClickHouse     3435
# 323052  platform_system_core     2233
# 311042             llama.cpp     2105
# 267633           aws-sdk-cpp     1930
# 263597            FarManager     1686
# ...                      ...      ...
# 119790        CVE-2018-15767        0
# 119789        CVE-2018-15766        0
# 119788        CVE-2018-15765        0
# 119787        CVE-2018-15764        0
# 176085        CVE-2021-27363        0
#
# [352171 rows x 2 columns]

# %%
software_name = 'libclutter-1.0-0'
software_version = '>= 1.12.0'

# %%
# Define the query
query = """
PREFIX sc: <https://w3id.org/secure-chain/>
PREFIX schema: <http://schema.org/>

SELECT ?software ?softwareName ?versionName
WHERE {
    # ?software a sc:Software .
    # ?software schema:name ?softwareName .
    # ?software sc:hasSoftwareVersion ?version .
    # ?version sc:versionName ?versionName .
}
LIMIT 100
"""

# Execute the query
results = g.query(query)

# Print results
for row in results:
    print(f"Software URI: {row.software}, Name: {row.softwareName}, Version: {row.versionName}")
# Out:
# Software URI: https://w3id.org/secure-chain/Software/sample_toplogy, Name: sample_toplogy, Version: 0.11.0
# Software URI: https://w3id.org/secure-chain/Software/libalberta2, Name: libalberta2, Version: 2.0.1-3
# Software URI: https://w3id.org/secure-chain/Software/libalberta2, Name: libalberta2, Version: 2.0.1-5
# Software URI: https://w3id.org/secure-chain/Software/createdebugutilsmessenger, Name: createdebugutilsmessenger, Version: *
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: 0.9-29-1
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: 0.9-25-1
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: 0.9-32-1
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: 0.9-27-1
# Software URI: https://w3id.org/secure-chain/Software/cyclonedds-cxx, Name: cyclonedds-cxx, Version: 0.10.4
# Software URI: https://w3id.org/secure-chain/Software/pmm_bootstrap, Name: pmm_bootstrap, Version: 2
# Software URI: https://w3id.org/secure-chain/Software/kf6-kauth, Name: kf6-kauth, Version: 6.4.0-1
# Software URI: https://w3id.org/secure-chain/Software/iossdk, Name: iossdk, Version: *
# Software URI: https://w3id.org/secure-chain/Software/pyside%24%7Bfreecad_qt_major_version%7Dtools, Name: pyside${freecad_qt_major_version}tools, Version: *
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.24.7-1
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.4.2-1
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.14.0-1
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.24.0-2
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.24.2-2
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.24.9-1
# Software URI: https://w3id.org/secure-chain/Software/gtkmm3.0, Name: gtkmm3.0, Version: 3.22.0-1
# Software URI: https://w3id.org/secure-chain/Software/libclutter-1.0-0, Name: libclutter-1.0-0, Version: >= 1.12.0
# Software URI: https://w3id.org/secure-chain/Software/libclutter-1.0-0, Name: libclutter-1.0-0, Version: >= 1.10.0
# Software URI: https://w3id.org/secure-chain/Software/libclutter-1.0-0, Name: libclutter-1.0-0, Version: >= 1.11.10
# Software URI: https://w3id.org/secure-chain/Software/libclutter-1.0-0, Name: libclutter-1.0-0, Version: >= 1.2.8
# Software URI: https://w3id.org/secure-chain/Software/exponentiate_gpu, Name: exponentiate_gpu, Version: *
# Software URI: https://w3id.org/secure-chain/Software/firebird2.5, Name: firebird2.5, Version: 2.5.3.26778.ds4-5+deb8u1
# Software URI: https://w3id.org/secure-chain/Software/firebird2.5, Name: firebird2.5, Version: 2.5.0.26054~ReleaseCandidate3.ds2-1+squeeze1
# Software URI: https://w3id.org/secure-chain/Software/firebird2.5, Name: firebird2.5, Version: 2.5.0.26054~ReleaseCandidate3.ds2-1+squeeze2
# Software URI: https://w3id.org/secure-chain/Software/firebird2.5, Name: firebird2.5, Version: 2.5.2.26540.ds4-1~deb7u2
# Software URI: https://w3id.org/secure-chain/Software/firebird2.5, Name: firebird2.5, Version: 2.5.3.26778.ds4-5
# Software URI: https://w3id.org/secure-chain/Software/libglew1.5-dev, Name: libglew1.5-dev, Version: *
# Software URI: https://w3id.org/secure-chain/Software/sofa-framework, Name: sofa-framework, Version: 1.0~beta4-4
# Software URI: https://w3id.org/secure-chain/Software/sofa-framework, Name: sofa-framework, Version: 1.0~beta4-9
# Software URI: https://w3id.org/secure-chain/Software/sofa-framework, Name: sofa-framework, Version: 1.0~beta4-11
# Software URI: https://w3id.org/secure-chain/Software/sofa-framework, Name: sofa-framework, Version: 1.0~beta4-7
# Software URI: https://w3id.org/secure-chain/Software/sofa-framework, Name: sofa-framework, Version: 1.0~beta4-12
# Software URI: https://w3id.org/secure-chain/Software/prometheus-cpp-pull, Name: prometheus-cpp-pull, Version: *
# Software URI: https://w3id.org/secure-chain/Software/libsigrokcxx4t64, Name: libsigrokcxx4t64, Version: >= 0.5.2
# Software URI: https://w3id.org/secure-chain/Software/hpx_mpi, Name: hpx_mpi, Version: *
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.6+dfsg-3build1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.3b+dfsg-10
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.6+dfsg-3
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.3b+dfsg-4
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.6.3b+dfsg-3.1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.6+dfsg-2build1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.3b+dfsg-10build2
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.3b+dfsg-9
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.3b+dfsg-4.1ubuntu1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.6+dfsg-1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.3b+dfsg-9build2
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.7.4b+dfsg-1~ubuntu12.04.1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.8.5b+dfsg-1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 1.0.1-1build4
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 1.0.1-1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.0b+dfsg-1
# Software URI: https://w3id.org/secure-chain/Software/fritzing-data, Name: fritzing-data, Version: 0.9.2b+dfsg-3
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: 4:18.04.1-1
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: 4:22.12.3-1
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:22.12.3
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:21.12.0
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:20.04.0
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: 4:16.08.2-1
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: 4:20.12.1-1
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:16.04.0
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:4.11
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:23.08.5
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:23.04.3
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:4.11.3
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:21.08.0
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: 4:4.13.3-1
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:20.12.0
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:22.12.0
# Software URI: https://w3id.org/secure-chain/Software/picmi, Name: picmi, Version: >= 4:17.08.3
# Software URI: https://w3id.org/secure-chain/Software/libdlt2, Name: libdlt2, Version: >= 2.18.4
# Software URI: https://w3id.org/secure-chain/Software/libdlt2, Name: libdlt2, Version: >= 2.18.5
# Software URI: https://w3id.org/secure-chain/Software/libdlt2, Name: libdlt2, Version: >= 2.18.6
# Software URI: https://w3id.org/secure-chain/Software/libdlt2, Name: libdlt2, Version: >= 2.18.10
# Software URI: https://w3id.org/secure-chain/Software/libdlt2, Name: libdlt2, Version: >= 2.18.8
# Software URI: https://w3id.org/secure-chain/Software/kernelshark, Name: kernelshark, Version: 2.2.1-1~deb12u1
# Software URI: https://w3id.org/secure-chain/Software/kernelshark, Name: kernelshark, Version: 2.2.1-1~bpo12+1
# Software URI: https://w3id.org/secure-chain/Software/kernelshark, Name: kernelshark, Version: 2.3.1-2
# Software URI: https://w3id.org/secure-chain/Software/motionbasic, Name: motionbasic, Version: *
# Software URI: https://w3id.org/secure-chain/Software/osgproducer, Name: osgproducer, Version: *
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: 4:20.12.2-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: 4:22.12.3-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:4.8.4+dfsg-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:3.5.5-3
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:4.11
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: 4:17.08.3-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: 4:16.08.3-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:3.5.0-2bpo1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:4.4.5-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: 4:4.14.2-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: 4:23.08.2-1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:23.08.5
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:4.8.5-0ubuntu0.1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:20.12.0
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:3.5.7-3~bpo40+1
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:21.08.0
# Software URI: https://w3id.org/secure-chain/Software/umbrello, Name: umbrello, Version: >= 4:3.3.2-3

# %%
# Sample query to check the existing data structure
test_query = """
PREFIX sc: <https://w3id.org/secure-chain/>
PREFIX schema: <http://schema.org/>

SELECT ?software ?name ?versionName
WHERE {
    # ?software a sc:Software ;
              schema:name ?name .
    OPTIONAL {
        # ?software sc:hasSoftwareVersion ?versionEntity .
        # ?versionEntity sc:versionName ?versionName .
    }
}
LIMIT 10
"""

for row in g.query(test_query):
    print(f"Software URI: {row.software}, Name: {row.name}, Version: {row.versionName if 'versionName' in row else 'No version'}")
# Out:
# Software URI: https://w3id.org/secure-chain/Software/sample_toplogy, Name: sample_toplogy, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/libalberta2, Name: libalberta2, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/libalberta2, Name: libalberta2, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/createdebugutilsmessenger, Name: createdebugutilsmessenger, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/r-cran-kernlab, Name: r-cran-kernlab, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/cyclonedds-cxx, Name: cyclonedds-cxx, Version: No version
# Software URI: https://w3id.org/secure-chain/Software/pmm_bootstrap, Name: pmm_bootstrap, Version: No version

# %%
from rdflib.plugins.sparql import prepareQuery

# Variables for the query
software_name = "libclutter-1.0-0"
software_version = ">= 1.12.0"

# Prepare the SPARQL query
sparql_query = prepareQuery("""
    PREFIX sc: <https://w3id.org/secure-chain/>
    PREFIX schema: <http://schema.org/>

    SELECT ?software ?version ?dependency
    WHERE {
        # ?software a sc:Software ;
                  schema:name ?name ;
                  sc:hasSoftwareVersion ?versionEntity .
        # ?versionEntity sc:versionName ?version ;
                       sc:dependsOn ?dependency .
    }
""", initNs={"sc": rdflib.URIRef("https://w3id.org/secure-chain/"),
             "schema": rdflib.URIRef("http://schema.org/")})

# Execute the query with parameters
results = g.query(sparql_query, initBindings={'name': rdflib.Literal(software_name),
                                              'version': rdflib.Literal(software_version)})

# Print results
#for row in results:
    #print(f"Software: {row.software}, Version: {row.version}, Dependency: {row.dependency}")

# %%
sparql_query = prepareQuery("""
    PREFIX sc: <https://w3id.org/secure-chain/>
    PREFIX schema: <http://schema.org/>

    SELECT ?software ?versionEntity ?dependency
    WHERE {
        # ?software a sc:Software ;
                  schema:name ?name ;
                  sc:hasSoftwareVersion ?versionEntity .
        # ?versionEntity sc:dependsOn ?dependency .
    }
""", initNs={"sc": rdflib.URIRef("https://w3id.org/secure-chain/"),
             "schema": rdflib.URIRef("http://schema.org/")})

results = g.query(sparql_query, initBindings={'name': rdflib.Literal(software_name)})

for result in results:
    print(f"Software: {result.software}, Version Entity: {result.versionEntity}, Dependency: {result.dependency}")

# %%
software_name = "libclutter-1.0-0"  # Example software name

from rdflib.namespace import RDF, RDFS, XSD
from rdflib.plugins.sparql import prepareQuery

# Namespaces might need to be defined based on your RDF structure
SC = rdflib.Namespace("https://w3id.org/secure-chain/")
SCHEMA = rdflib.Namespace("http://schema.org/")

# Prepare the SPARQL query
query = prepareQuery("""
    SELECT ?software
    WHERE {
        # ?software a sc:Software ;
                  schema:name ?name .
        FILTER (?name = ?exactName)
    }
""", initNs={"sc": SC, "schema": SCHEMA})

# Execute the query with parameters
results = g.query(query, initBindings={'exactName': rdflib.Literal(software_name)})

# Print results
for row in results:
    print(f"Software URI: {row.software}")
# Out:
# Software URI: https://w3id.org/secure-chain/Software/libclutter-1.0-0

# %%
# Initialize lists to hold column data
software_uris = []
versions = []
dependencies = []

# Iterate through the results
for row in results:
    software_uris.append(str(row.software))
    versions.append(str(row.version))
    dependencies.append(str(row.dependency))

# Create DataFrame
df = pd.DataFrame({
    'Software URI': software_uris,
    'Version': versions,
    'Dependency': dependencies
})

# Display the DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 9
#       7 for row in results:
#       8     software_uris.append(str(row.software))
# ----> 9     versions.append(str(row.version))
#      10     dependencies.append(str(row.dependency))
#      12 # Create DataFrame
#
# File ~/miniconda3/envs/kg-env/lib/python3.10/site-packages/rdflib/query.py:166, in ResultRow.__getattr__(self, name)
#     164 def __getattr__(self, name: str) -> Identifier:
#     165     if name not in self.labels:
# --> 166         raise AttributeError(name)
#     167     return tuple.__getitem__(self, self.labels[name])
#
# AttributeError: version

# %%
query_relationships = """
SELECT ?s ?p ?o
WHERE {
    # ?s ?p ?o .
    FILTER (isURI(?s) && isURI(?o))
}
LIMIT 10
"""

results = g.query(query_relationships)

# Collect data into a list of dictionaries
data = []
for row in results:
    data.append({
        "subject": str(row.s),
        "predicate": str(row.p),
        "object": str(row.o)
    })

# Convert the list to a DataFrame
df_relationships = pd.DataFrame(data)


df_relationships
# Out:
#                                                                                subject  \
# 0                        https://w3id.org/secure-chain/SoftwareVersion/Camomile#v1.0.7
# 1                     https://w3id.org/secure-chain/HardwareVersion/alienware_m17_r2#-
# 2                              https://w3id.org/secure-chain/HardwareVersion/wsa8810#-
# 3                           https://w3id.org/secure-chain/SoftwareVersion/curve#v0.1.2
# 4                       https://w3id.org/secure-chain/SoftwareVersion/xournalpp#v1.1.1
# 5                                   https://w3id.org/secure-chain/Software/peony-admin
# 6                           https://w3id.org/secure-chain/Vulnerability/CVE-2020-36065
# 7           https://w3id.org/secure-chain/SoftwareVersion/ClickHouse#v22.6.6.16-stable
# 8  https://w3id.org/secure-chain/HardwareVersion/latitude_7230_rugged_extreme_tablet#-
# 9                https://w3id.org/secure-chain/Hardware/color_laserjet_pro_m453_w1y45a
#
#                                          predicate  \
# 0          https://w3id.org/secure-chain/dependsOn
# 1       https://w3id.org/secure-chain/vulnerableTo
# 2       https://w3id.org/secure-chain/vulnerableTo
# 3          https://w3id.org/secure-chain/dependsOn
# 4          https://w3id.org/secure-chain/dependsOn
# 5  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 6  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 7          https://w3id.org/secure-chain/dependsOn
# 8       https://w3id.org/secure-chain/vulnerableTo
# 9  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                                     object
# 0                https://w3id.org/secure-chain/SoftwareVersion/pthread#%2A
# 1               https://w3id.org/secure-chain/Vulnerability/CVE-2022-32488
# 2               https://w3id.org/secure-chain/Vulnerability/CVE-2023-33085
# 3             https://w3id.org/secure-chain/SoftwareVersion/nebdclient#%2A
# 4  https://w3id.org/secure-chain/SoftwareVersion/%22gtk%2B-3.0+#+3.18.9%22
# 5                                   https://w3id.org/secure-chain/Software
# 6                              https://w3id.org/secure-chain/Vulnerability
# 7            https://w3id.org/secure-chain/SoftwareVersion/tls_library#%2A
# 8               https://w3id.org/secure-chain/Vulnerability/CVE-2023-25938
# 9                                   https://w3id.org/secure-chain/Hardware

# %%
df2 = df.copy()

# %%
# Function to extract the segment before the product name
def extract_segment(uri):
    # Decode the URI to handle URL-encoded characters like '%3E'
    uri = urllib.parse.unquote(uri)
    
    # Split by '/' and get the second to last element which should be 'SoftwareVersion'
    parts = uri.split('/')
    if len(parts) > 1:
        return parts[-2]  # Returns 'SoftwareVersion'
    return None

# Apply the function to the 'subject' column
df2['segment'] = df2['subject'].apply(extract_segment)

# %%
df2['segment'].unique()
# Out:
# array(['SoftwareVersion', 'HardwareVersion', 'melsec_iq-fx5s-60mr\\',
#        'fx5s-80mt\\', '', 'fx3u-16mt\\', 'x9drff-7\\', 'ds-2xe6242f-is\\',
#        '4331\\', '50\\', 'vg400-4fxs\\', 'ds-2cd3026g2-iu\\',
#        '762-6201\\', '6186\\', 'ds-2cd2386g2-isu\\', 'event_engine',
#        'synergy\\', 'scientific_atlanta_dpx\\', 'lan-w300n\\',
#        'nim-4mft-t1\\', 'fx5u-64mr\\', 'xec-dr64h\\', 'fx3g-40mr\\',
#        'absl', '750-8208\\', 'ilc_151_eth\\', '750-8212\\', 'xbc-dn32h\\',
#        '750-880\\', 'rc-s310\\', 'fx3uc-64mt\\', 'lan-wh300an\\',
#        'melsec_iq-fx5u-64mt\\', 'ip38x\\', 'mguard_rs4004_tx\\',
#        'rv13frlm\\', 'third_party', 'toolchain', 'src', 'fx3g-60_mt\\',
#        'melsec_iq-fx5s-30mr\\', 'siplus_s7-1500_cpu_1516-3_pn\\',
#        'n540-28z4c-sys-a\\', 'fl_switch_smn_6tx\\',
#        'simatic_s7-1517f-3_pn\\', 'anywhereusb\\', 's5552\\',
#        'fx3u-128mr\\', 'optima_nm\\', 'thinkcentre_m715t\\',
#        'ds-3wf01c-2n\\', 'fx3ge-24mr\\', '762-4301\\', 'ilc_131_eth\\',
#        'xbc-dr32h\\', 'ds-7604ni-q1\\', 'flow-x\\', 'fx3s-10mt\\',
#        'fx5u-64mt\\', '42\\', 'siplus_cpu-1516f-3_pn\\', 'sd_8\\',
#        'scientific_atlanta_dpc\\', 'hdl2-a\\', 'rv7frm\\',
#        'melsec_iq-fx5u-64mr\\', 'ds-2td1217b-3\\', 'dir-825\\',
#        'rv13frm\\', 'fx3u-64mt\\', 'qlogic_20-port_4\\', '750-364\\',
#        'procurve_switch_5406zl-44g-poe\\+\\', 'nvr5216-8p-i\\',
#        'ds-7608ni-k1\\', '750-8202\\', 'fx3uc-16mt\\', 'crs-8\\',
#        'stories_rw4002_601\\', '35\\', 'lan-wh300n\\', 'xbc-dr28u\\',
#        'fx3u-48mr\\', '12\\', 'fx3s-14mt\\', '762-5306\\',
#        'bently_nevada_3500\\', 'simatic_s7-1500_cpu_1518-4_pn\\',
#        '8.1.0\\', 'thinkcentre_e75_t\\', 'x9drw-3ln4f\\+\\',
#        'h170m-plus\\', 'adsl2\\', 'fx5uj-60mt\\', 'fx3s-30mr\\',
#        'nvr4432-16p-4ks2\\', 'esc8000_g4\\', '762-6302\\',
#        'thinkcentre_m4600t\\', 'wago_i\\', 'seil\\', '762-4305\\',
#        'xgi-cpuu\\', 'scalance_xb213-3_\\(sc\\,_e\\', '4351\\',
#        'eagle_20_tofino_943_987-505-mm\\', 'fx3s-10mr\\', '762-6202\\',
#        'thinkcentre_m6500t\\', 'ds-2td1117-3\\', 'widoco',
#        'simatic_s7-400pn\\', 'melsec_iq-fx5u-32mt\\', 'fx3g-40_mr\\',
#        'x9dr7\\', 'msz-ap60\\', 'at-gs950\\', 'fx3u-128mt\\',
#        'prime_z270m-plus\\', 'se4082s1t2b8_high_side_40-pin_do_mass_i\\',
#        'fx3u-80mt\\', 'yangtian_me\\', '60\\', 'xec-dn\\(p\\)32u\\',
#        'simatic_s7-1516f-3_pn\\', 'melsec_iq-fx5u-32mr\\',
#        'utc_fire_\\&_security_ge-mc100-ntp\\', 'melsec_iq-fx5uj-40mt\\',
#        'nvr5832\\', 'storeever_1\\', 'fx3g-40mt\\', '06\\',
#        'simatic_s7-1500_cpu_s7-1518-4_pn\\', 'siplus_cpu_1518-4_pn\\',
#        'fx3u-32mt\\', 'fx5uc-32mt\\', 'melsec_iq-fx5uj-60mt\\', 'o_-25\\',
#        'fl_mguard_rs4000_tx\\', 'melsec_iq-fx5uj-24mr\\',
#        'mguard_delta_tx\\', 'fx3g-24mt\\',
#        "curlpp#m4_esyscmd_s([sed+-ne+'s", 'recorder\\', 'dir-815\\',
#        'melsec_iq-fx5u-80mr\\', 'fx3u-48mt\\', 'simatic_s7-1517-3_pn\\',
#        '16\\', 'xec-dn\\(p\\)32ua\\',
#        'bentley_nevada_3500_system_1_6.x_\\(3060\\',
#        'thinkcentre_m6600t\\', '1756-enbt\\', 'nim-2mft-t1\\',
#        'ds-7608ni-q2\\', 'fx3u-32mr\\', 'fx3g-32_mt\\', 'ethernet_i\\',
#        'melsec_iq-fx5uc-64mr\\', 'icrl-m-8rj45\\', 'fx3g-24_mt\\',
#        'ds-kd8003ime1\\(b\\)\\', 'simatic_s7-400_cpu_414-3_pn\\',
#        'scalance_xc206-2sfp_g_\\(e\\', 'ex8200\\',
#        'scientific_atlanta_dpq\\', 'bently_nevada_3701\\',
#        'innominate_mguard_rs4000_4tx\\', 'ds-2cd2046g2-iu\\', 'wn-g54\\',
#        'fx3g-24mr\\', 'fx3ge-40mr\\', 'g-cam\\', 'o_-40\\',
#        'dvg-n5402g\\', 'simatic_cp_1243-7_lte\\', 'ds-2td8166-100c2f\\',
#        'se4037p0_h1_i\\', 'fx3s-30mt\\', '1734-aentr_point_i\\',
#        'fx5uj-24mt\\', 'melsec_iq-fx5uj-40mr\\', 'simotion_d445-2_dp\\',
#        'fx3g-14mt\\', 'z\\',
#        'se4039p0_redundant_h1_4-port_plus_fieldbus_i\\',
#        'melsec_iq-fx5uc-32mr\\', 'fx5uj-60mr\\', 'fx3u-64ms\\',
#        'pc10pe-16\\', 'fx5uc-96mt\\', 'wn-gdn\\', 'ds-2cd3326g2-isu\\',
#        'nexus_3548-x\\', 'fx3uc-96mt\\', 'nvr4832-16p-4ks2\\',
#        'simatic_s7-300_cpu_319-3_pn\\', 'fx3g-14mr\\', 'h110m-c2\\',
#        'cpu_1517-3_pn\\', 'n540x-12z16g-sys-a\\', 'sinamics_s\\',
#        'rg-nbs3200-24sfp\\', '2x230\\', 'simatic_s7-400_cpu_416-3_pn\\',
#        '29\\', 'simatic_s7-1500_cpu_1517-3_pn\\', 'fx5uj-40mr\\',
#        'eagle_20_tofino_943_987-504-mm\\', 'se4003s2b524-pin_mass_i\\',
#        'logo\\!', 'tensorflow', 'laserjet_4l\\', 'wifi\\', 'fx3s-20mt\\',
#        'ds-2cd2666g2-izsu\\', 'melsec_iq-fx5uc-32mt\\', 'ds-2td4137-25\\',
#        'melsec_iq-fx5s-30mt\\', 'xgr-cpuh\\', 'melsec_iq-fx5u-80mt\\',
#        'cdm\\', 'icrl-m-16rj45\\', 'melsec_iq-fx5uc-64mt\\',
#        'centrecom_9924t\\', 'nim-1mft-t1\\', '898_secure_g.shdsl_efm\\',
#        'killer_wi-fi_6e_ax1675x\\', 'killer_wi-fi_6_ax1650i\\', '16x\\',
#        'simatic_s7-1518f-4_pn\\', 'rv7frllm\\', 'x9drd-l\\',
#        'fx3g-60mt\\', 'fx5u-80mt\\', 'fx3u-32ms\\', '750-8210\\', '13\\',
#        'simotion_d435-2_dp\\', 'ds-2td8166-150ze2f\\', 'fx5s-60mr\\',
#        'simatic_s7-400_pn\\', 'avalon_fetal\\',
#        'scientific_atlanta_dpx100\\', 'monitor\\', 'exper\\',
#        'ds-2cd2321g0-i\\', 'mds', 'client', 'stardom_fcn\\',
#        'se4801t0x_redundant_wireless_i\\',
#        'aruba_instant_on_1930_24g_4sfp\\', 'sinamics_g110m\\', 'otel',
#        'ds-2td6267-75c4l\\', 'express5800\\', 'b\\', '762-4204\\',
#        'nameserver2', '762-4303\\', 'fx3ge-40mt\\', 'snapdragon_855\\+\\',
#        '32\\', 'scientific_atlanta_dpc3008\\', '762-4203\\', 'x9drl-7\\',
#        'g\\', 'x9dax-7\\', 'bacnet\\', 'value_serial\\',
#        'melsec_iq-fx5s-40mr\\', 'snmp\\', 'simotion_d425-2_dp\\', '8\\',
#        'nexus_3524-x\\', 'yangtian_mf\\',
#        'eagle_20_tofino_943_987-502_-tx\\', 'fx3g-60_mr\\', 'ds-kd-kp\\',
#        'fx3g-14_mt\\', 'se4100_simplex_ethernet_i\\', 'nvr-104mh-c\\',
#        'fx3s-14mr\\', 'ts-ptcam\\', 'ds-2cd2346g2-isu\\', 'fx3g-14_mr\\',
#        'fx3u-80mr\\', 'vg400-2fxs\\', '750-890\\', '762-4201\\',
#        'mguard_rs4000_tx\\', 'rp7_single_head_msr_w\\', 'discovery_nm\\',
#        'explorer', 'hdl-a\\', 'storageworks_1\\',
#        'procurve_switch_5412zl-92gg-poe\\+\\', 'fx3u-16mr\\',
#        'b150i_pro_gaming\\', '750-832\\', '8p\\', '100\\',
#        'scalance_xp208_\\(ethernet\\', 'x9db3\\', 'p\\', '750-8216\\',
#        'ds-2cd2347g2-lsu\\', 'siplus_s7-300_cpu_315-2_pn\\',
#        'fx3u-64mr\\', 'ds-2td8167-230zg2f\\', 'fl_mguard_rs4004_tx\\',
#        'chromebook_11_g4\\', 'ds-2td8167-150zc4f\\', '750-8211\\',
#        'se4801t1x_simplex_wireless_i\\', 'melsec_iq-fx5s-80mr\\',
#        'etherhaul_70\\', '1100-4g\\', '750-8217\\',
#        'killer_wi-fi_6e_ax1690i\\', 'dap-3520_h\\', 'x9drl-3\\',
#        'ts-wrlp\\', 'simatic_pn\\', 'slc5\\', 'fx5u-32mr\\',
#        'xec-dr28up\\', 'xbc-dr28up\\', 'nexus_3172pq\\', 'rad-80211-xd\\',
#        'x9drw-7\\', 'simatic_s7-1500_cpu_1518-4f_pn\\',
#        'fl_switch_2506-2sfp\\', 'ds-7616ni-e2\\',
#        'procurve_switch_5412zl-92g-poe\\+\\',
#        'integrated_single_head_w\\', 'scalance_xb205-3_\\(st\\,_e\\',
#        'b150m-c\\', 'xbc-dr64h\\', 'simatic_s7-1518-4_pn\\', '762-5305\\',
#        'mguard_gt\\', 'nvr4832-4ks2\\', 'ilc_191_me\\', 'msz-ft20\\',
#        'scalance_xb216_\\(e\\', 'simatic_s7-400_cpu_416f-3_pn\\',
#        'fx5s-80mr\\', 'se4019p0_simplex_h1_4-port_plus_fieldbus_i\\',
#        'nvr5216-16p-i\\', 'fx5s-40mt\\', 'upb', 'ds-2cd2686g2-izsu\\',
#        'ds-7104ni-q1\\', 'ds-2td6267-50h4l\\',
#        'scalance_xp216_\\(ethernet\\', '01\\', 'nvr4416-4ks2\\', 'tg\\',
#        'ds-2td8166-150zh2f\\', 'bladecenter_layer_2\\',
#        'ds-2cd3356g2-isu\\', '852-111\\', 'k22-80\\',
#        'simatic_et200sp_im155-6_pn\\', 'ds-2td8166-75c2f\\', 'nds\\',
#        'ts-wlcam\\', 'rad-ism-900-en-bd\\', 'xbc-dn\\(p\\)32ua\\',
#        'lcd\\', 'prime_b250m-plus\\', 'ds-7608ni-e1\\', 'mpx\\',
#        'ds-2cd2326g2-isu\\', 'ds-2cd3056g2iu\\', 'ds-7616ni-q2\\',
#        'smp_4\\', 'fl_switch_smcs_6gt\\', 'thinkcentre_m710t\\',
#        'thinkcentre_m4500t\\', 'fx3g-24_mr\\', 'ds-2td6267-100c4l\\',
#        'vg450-144fxs\\', '11\\', 'gxv3611hd\\', 'psi-modem\\',
#        'fx3ge-24mt\\', '750-8101\\', '2530_10\\', 'vg420-84fxs\\',
#        'fx5u-32mt\\', 'x9drh-7\\', 'ds-2td4137-50\\', 'ds-2td4167-25\\',
#        '4321\\', 'o_ethernet\\', 'officeconnect_1850_2xgt\\',
#        'laserjet_4\\', 'flex_i\\', 'ds-2td8166-180ze2f\\',
#        'z170_pro_gaming\\',
#        've4107_iec_61850_mms_interface_for_ethernet_connected_i\\',
#        'melsec_iq-fx5uj-24mt\\', '750-8207\\', 'ds-2cd2066g2-iu\\',
#        'fx5u-80mr\\', 'melsec_iq-fx5uj-60mr\\', '762-6304\\',
#        'nport_ia5000a-i\\', 'siplus_s7-1500_cpu_1518-4_pn\\',
#        'fx3uc-32mt\\', 'ds-7108ni-q1\\', 'se4027_virtual_i\\', 'cap\\',
#        'cpp', 'ie\\', '762-5304\\', 'fl_mguard_gt\\',
#        'killer_wireless-ac_1550i\\', 'fl_switch_smcs_6tx\\',
#        'aruba_instant_on_1930_24g_class4_poe_4sfp\\',
#        'nport_iaw5150a-6i\\', 'fx5uj-40mt\\', '423-41w\\', '762-5204\\',
#        '20\\', 'nvr4416-16p-4ks2\\', 'fx3g-60mr\\', 'ds-2cd3056g2-iu\\',
#        'sm-x-1t3\\', 'vg450\\', 'netborder\\', 'fx3g-40_mt\\', '422\\',
#        'o_1794-aent\\', 'bladecenter_1\\', 'sy-780\\',
#        'siplus_cpu_1518f-4_pn\\', 'simatic_et_200sp_im_155-6_pn\\',
#        'yangtian_tc\\', 'eagle_20_tofino_943_987-501-tx\\',
#        'melsec_iq-fx5s-40mt\\', 'quantum_hd_unity_condenser\\',
#        '762-6203\\', 'simatic_s7-1500_cpu_1516-3_pn\\', '0852-1305\\',
#        'cpu_1517tf-3_pn\\', 'cs1000e\\', 'at-8624t\\', '750-362\\',
#        'fx3s-20mr\\', 'biograph_horizon_pet\\',
#        'storageworks_p2000_g3_msa_fc\\', 'n540x-16z4g8q2c-a\\',
#        'rog_strix_z270h_gaming\\', 'h110m-e\\', '3g\\', 'h110m-a\\',
#        'nim-4bri-nt\\', 'xec-dr32h\\', 'simatic_s7-400_cpu_414f-3_pn\\',
#        'enhanced_layer_2\\', 'xbc-dn\\(p\\)32up\\', 'x9da7\\',
#        '750-8204\\', 'se4017p0_h1_i\\', 'ois-1.0-sd',
#        'integrated_single_head_msr_w\\', 'z11pa-u12\\', 'ds-2td1117-2\\',
#        'ld-ps\\', 'h110m-c\\', 'se4026_virtual_i\\',
#        'bentley_nevada_3500\\', 'simatic_s7-1516-3_pn\\', 'ilc_1x1_gsm\\',
#        'ex2200\\', 'fx5uc-64mt\\', 'melsec_iq-fx5s-60mt\\',
#        'el_ppc_1000\\', 'simotion_d455-2_dp\\', 'emc_ix2\\',
#        'simatic_s7-1500_cpu_1517t-3_pn\\', 'laserjet_4p\\', '762-4206\\',
#        '750-363\\', 'x9dbu-3\\', 'fx3gc-32mt\\', 'fl_mguard_delta_tx\\',
#        'laserjet_4_plus\\', 'se4101_simplex_ethernet_i\\', 'x9dr3\\',
#        'ds-2cd2366g2-isu\\', 'nvr5864-i\\', '2001', 'h110m-p\\',
#        '897_multi-mode_vdsl2\\', 'ds-2td1217b-6\\', 'xbc-dr28ua\\',
#        'connectport_ts_8\\', 'ds-7616ni-12\\', 'msz-exa09\\',
#        'vg400-6fxs\\', 'ds-kd-kk\\', 'syncbox\\', 'ex3300\\',
#        'sailor_6300_mf_\\', 'cpu_1516tf-3_pn\\',
#        'scalance_xb213-3_\\(st\\,_e\\', 'melsec_iq-fx5s-80mt\\',
#        'scientific_atlanta_dpc3000\\', 'sm-x_layer_2\\', 'ar_28\\',
#        'scalance_xb205-3ld_\\(sc\\,_e\\', 'mfz-xt50\\', 'ds-7608ni-12\\',
#        'ws_x299_pro\\', '762-4306\\', 'gxv3601hd\\', '762-4202\\',
#        'thinkcentre_m700t\\', 'xec-dr28ua\\', '750-8213\\',
#        'scalance_xc216-4c_g_\\(e\\', 'rv4frlm\\',
#        'simatic_s7-300_cpu_315-2_pn\\', 'sandboxed_api', 'gxv3615w\\',
#        'b150_pro_gaming\\', 'laserjet_5p\\', 'nim-2fxs\\', '22\\',
#        'fl_mguard_rs2000_tx\\',
#        've4106_opc-ua_client_for_ethernet_connected_i\\',
#        'melsec_iq-fx5uc-96mt\\', 'dvg-5402g\\', 'nport_iaw5250a-6i\\',
#        '896_multi-mode_vdsl2\\', 'cpu_1518-4_pn\\', 'pc10b-e\\',
#        '750-8206\\', '762-4205\\', 'sms\\', '762-6303\\', 'nvr-108h-d\\',
#        'ip_interface_for_ethernet_connected_i\\', '762-4304\\',
#        'xec-dr28u\\', 'scalance_xb208_\\(e\\', 'rv20frm\\', 'x9dal-3\\',
#        'fx5s-30mt\\', 'flex_io_1794-aent\\', '762-5205\\', 'ex4550\\',
#        'mguard_rs2000_tx\\', 'nexus_3132q-x\\', 'fx5s-30mr\\',
#        'se4002s1t2b6_high_side_40-pin_mass_i\\', 'cc2540\\',
#        'dap-1353_h\\', 'dir-895\\', 'ne40e\\', 'nport_iaw5250a-12i\\',
#        'g3_gsm\\', '887_multi-mode_vdsl2\\', 'wi-fi\\', '762-5303\\',
#        'nvr-108mh-d\\', 'killer_wi-fi_6e_ax1675i\\', 'ds-7604ni-e1\\',
#        'nvr4816-4ks2\\', 'ids-2sk8144ixs-d\\', 'thinkcentre_m8600t\\',
#        'xec-dn\\(p\\)32up\\', 'se4032s1t2b8_high_side_40-pin_do_mass_i\\',
#        'se4003s2b4_16-pin_mass_i\\', 'aruba_instant_on_1930_48g_4sfp\\',
#        'nvr4816-16p-4ks2\\', 'nvr5832-i\\', 'fl_switch_2508\\',
#        '750-8102\\', 'tofino_argon_fa-tsa-220-tx\\',
#        've4103_modbus_tcp_interface_for_ethernet_connected_i\\',
#        'nvr-104mh-d\\', 'tofino_argon_fa-tsa-100-tx\\',
#        'simatic_s7-1500_cpu_1517f-3_pn\\', 'nport_iaw5000a-i\\',
#        '752-8303\\', 'fl\\', 'nim-8mft-t1\\', 'cpu_1517t-3_pn\\',
#        'sensor_wireless_i\\', 'nvr-108mh-c\\', 'msz-fx20\\',
#        'tofino_argon_fa-tsa-220-mm\\', 'touchstone_tg862g\\', 'nim-4e\\',
#        'sft_dab_600\\', 'cpu_1516t-3_pn\\', 'nvr-208mh-c\\',
#        'nvr4432-4ks2\\', 'siplus_s7-1500_cpu_1516f-3_pn\\',
#        'ds-7716ni-sp\\', 'cpu_1517f-3_pn\\', 'a900-rsp3c-400\\',
#        'siplus_cpu_1516-3_pn\\', 'simatic_s7-1500_cpu_1518t-4_pn\\',
#        'xbc-dn64h\\', 'scientific_atlanta__dpr\\',
#        'simatic_s7-1500_cpu_1518f-4_pn\\', 'vg420-132fxs\\',
#        'simatic_s7-300_cpu_317-2_pn\\', 'z170m-plus\\',
#        'n540-12z20g-sys-a\\', '750-885\\', 'xbc-dn\\(p\\)32u\\',
#        'fx5-enet\\', 'procurve_switch_2610-24\\', 'ds-2df8a442ixs-af\\',
#        'bentley_nevada_3500_system_1_\\(3071\\',
#        'flex_system_fabric_en4093\\', 'siplus_s7-1500_cpu_1518f-4_pn\\',
#        '10500\\', 'simatic_s7-1500_cpu_1516tf-3_pn\\',
#        'ds-2td8167-190ze2f\\', 'ds-2td4167-50\\', 'rv4frm\\',
#        'ds-7608ni-q1\\', 'revolution_xq\\', 'x9drw-3\\',
#        'fl_switch_smcs_14tx\\', 'ethernet\\',
#        'simatic_s7-1500_cpu_1516t-3_pn\\', '0852-1505\\', '70\\',
#        'ds-7716ni-14\\', 'simatic_s7-1500_cpu_s7-1518f-4_pn\\',
#        'ws_c422_pro\\', 'merten_knx_argus_180\\', 'drm-1\\',
#        'allen-bradley_flex_io_1794-aent\\', 'simatic_ie\\', 'x9dbl-3\\',
#        '4p\\', 'simatic_s7-1500_cpu_1517tf-3_pn\\',
#        'bentley_nevada_3500_system_1_\\(3072\\', 'emc_px12-400r\\',
#        'fx5uj-24mr\\', 'dir-890l\\', 'rg-nbs5200-24sfp\\',
#        'tiger_lake_h\\', 'sda\\', 'nbn-498_dinion2x_day\\',
#        'ds-760ni-k1\\', 'scalance_xc224-4c_g_\\(e\\', '750-831\\',
#        'b150m-a\\', 'encs5412\\',
#        'se4052s1t2b6_high_side_40-pin_mass_i\\', 'fx5uc-32mr\\',
#        'aruba_instant_on_1930_48g_class4_poe_4sfp\\',
#        'ds-2cd2626g2-izsu\\', 'lan-wh450n\\', 'h110m-cs\\', 'fx5s-60mt\\',
#        'cpu_1518f-4_pn\\', 'scalance_xc206-2_\\(st\\', 'x9sre\\',
#        '710s-13ikb\\', 'h170-pro\\', '750-8203\\', 'vocommons',
#        'dap-2553_h\\', '762-4302\\', 'ds-2td6237-75c4l\\',
#        'ds-2cd2646g2-izsu\\', '750-365\\', 'rv7frlm\\',
#        'simocode_prov_ethernet\\', 'fx3uc-16mr\\', 'ds-2cd2027g2-lu\\',
#        'simotion_d410-2_dp\\', 'nvr5432-16p-i\\',
#        'se4037p1_redundant_h1_i\\', 'ds-2cd2026g2-iu\\', 'fx5s-40mr\\',
#        '762-6204\\', '71\\', 'ds-2td6237-50h4l\\', '499es_ethernet\\',
#        '762-6301\\', 'nim-2bri-nt\\', '762-5206\\', '64\\',
#        'nvr-216mh-c\\', 'melsec_iq-fx5uc-96mr\\', 'rc-s380\\',
#        'se4017p1_h1_i\\', 'ncr\\', 'ids-2pt9a144mxs-d\\',
#        'siplus_s7-300_cpu_317-2_pn\\', 'yangtian_ms\\', 'remote_cap\\',
#        '710s-13isk\\', 'at-8648t\\', 'm\\', '762-5203\\', 'laserjet_4v\\',
#        'thinkcentre_m910_t\\', 'scalance_xb213-3ld_\\(sc\\,_e\\',
#        'fl_switch_2316\\', 'simatic_s7-1500_cpu_1516f-3_pn\\',
#        'dir-885\\', 'ds-2cd2086g2-iu\\', '8100l\\', 'ds-2td1117-6\\',
#        'thinkcentre_m8500t\\', '4g\\', 'vg450-72fxs\\',
#        'nport_iaw5150a-12i\\', 'msz-eza09\\', 'scalance_xc208g_\\(e\\',
#        'pn\\', 'ip_control_tag_integration_for_ethernet_connected_i\\',
#        'prime_h110m2\\', 'ipam_transmitter_f\\',
#        'simatic_s7-1500_cpu_1518tf-4_pn\\', 'thinkcentre_m910t\\',
#        'dtl201b\\'], dtype=object)

# %%
df1 = df[['product', 'version']].groupby('product').count().reset_index().sort_values(by='version', ascending=False)
df1
# Out:
#                     product  version
# 3646             ClickHouse     3435
# 63059  platform_system_core     2233
# 51063             llama.cpp     2105
# 7718            aws-sdk-cpp     1930
# 3744             FarManager     1686
# ...                     ...      ...
# 33480          jetwave_4510        1
# 33479      jetwave_4221hp-e        1
# 33478       jetwave_3420_v3        1
# 33476       jetwave_3220_v3        1
# 46074       libnunit2.5-cil        1
#
# [92149 rows x 2 columns]

# %%
query = """
SELECT DISTINCT ?s
WHERE {
    # ?s ?p ?o .
    FILTER (isURI(?s))
}
LIMIT 10
"""

# %%
results = g.query(query)

# %%
data = []
for row in results:
    data.append({"subject": str(row.subject)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 3
#       1 data = []
#       2 for row in results:
# ----> 3     data.append({"subject": str(row.subject)})
#
# File ~/miniconda3/envs/kg-env/lib/python3.10/site-packages/rdflib/query.py:166, in ResultRow.__getattr__(self, name)
#     164 def __getattr__(self, name: str) -> Identifier:
#     165     if name not in self.labels:
# --> 166         raise AttributeError(name)
#     167     return tuple.__getitem__(self, self.labels[name])
#
# AttributeError: subject

# %%
query_properties = """
SELECT DISTINCT ?property
WHERE {
    # ?s ?property ?o .
    FILTER (isURI(?property))
}
"""
results = g.query(query_properties)

# Collect data into a list of dictionaries
data = []
for row in results:
    data.append({"property": str(row.property)})

# %%
df_properties = pd.DataFrame(data)

# %%
df_properties
# Out:
#                                                property
# 0               https://w3id.org/secure-chain/dependsOn
# 1            https://w3id.org/secure-chain/vulnerableTo
# 2                          http://schema.org/identifier
# 3       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4                                http://schema.org/name
# 5                        http://schema.org/manufacturer
# 6             https://w3id.org/secure-chain/versionName
# 7      https://w3id.org/secure-chain/hasSoftwareVersion
# 8       https://w3id.org/secure-chain/vulnerabilityType
# 9      https://w3id.org/secure-chain/hasHardwareVersion
# 10                        http://schema.org/contributor
# 11                                http://schema.org/url
# 12              http://purl.org/dc/elements/1.1/creator
# 13     http://www.w3.org/2000/01/rdf-schema#isDefinedBy
# 14         http://www.w3.org/2000/01/rdf-schema#comment
# 15           http://www.w3.org/2000/01/rdf-schema#range
# 16                     http://purl.org/dc/terms/license
# 17      http://www.w3.org/2000/01/rdf-schema#subClassOf
# 18             http://purl.org/dc/elements/1.1/abstract
# 19          http://www.w3.org/2000/01/rdf-schema#domain
# 20               http://purl.org/vocommons/voaf#extends
# 21     http://www.w3.org/1999/02/22-rdf-syntax-ns#first
# 22      http://www.w3.org/1999/02/22-rdf-syntax-ns#rest
# 23             http://www.w3.org/2002/07/owl#versionIRI
# 24           http://www.w3.org/2000/01/rdf-schema#label
# 25                http://purl.org/dc/elements/1.1/title
# 26                http://www.w3.org/2002/07/owl#unionOf
# 27           https://w3id.org/widoco/vocab#introduction
# 28            http://www.w3.org/2002/07/owl#versionInfo
# 29  http://purl.org/vocab/vann/preferredNamespacePrefix
# 30          http://purl.org/dc/elements/1.1/description
# 31     http://purl.org/vocab/vann/preferredNamespaceUri
# 32                     http://purl.org/dc/terms/created

# %%
df_properties[['property_type', 'software_version']] = df_properties['subject'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)
df_properties[['software', 'version']] = df_properties['software_version'].str.split('#', expand=True)
df_properties['predicate_type'] = df_properties['predicate'].apply(lambda x: x.split('/')[-1].split('#')[-1])
df_properties[['object_type', 'object_detail']] = df_properties['object'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)

df_properties2 = df_properties[['property_type', 'software', 'version', 'predicate_type', 'object_type', 'object_detail']]

# %%
df_properties2.to_csv('properties.csv', index=False)
df_properties2.head()
# Out:
#      property_type        software                  version  \
# 0  SoftwareVersion      Clementine  1.4.0rc1-689-g6982b4781
# 1  SoftwareVersion  ibus-libpinyin          1.15.1-1ubuntu1
# 2  SoftwareVersion      Clementine  1.4.0rc1-614-g89831f8dc
# 3    Vulnerability   CVE-2015-9177                     None
# 4  SoftwareVersion      ClickHouse           v23.3.10.5-lts
#
#       predicate_type        object_type  \
# 0          dependsOn    SoftwareVersion
# 1          dependsOn    SoftwareVersion
# 2          dependsOn    SoftwareVersion
# 3  vulnerabilityType  VulnerabilityType
# 4          dependsOn    SoftwareVersion
#
#                                       object_detail
# 0                                  libpulse-dev#%2A
# 1                       dconf-gsettings-backend#%2A
# 2                             qtbase5-dev-tools#%2A
# 3                                           CWE-119
# 4  icudata#c8e717892a557b4d2852317c7d628aacc0a0e5ab

# %%
len(df_properties)
# Out:
# 17

# %%
df_properties2['property_type'].unique()

# %%
import pandas as pd

# %%
query_relationships = """
SELECT ?s ?p ?o
WHERE {
    # ?s ?p ?o .
    FILTER (isURI(?s) && isURI(?o))
}
LIMIT 10000
"""

results = g.query(query_relationships)

# Collect data into a list of dictionaries
data = []
for row in results:
    data.append({
        "subject": str(row.s),
        "predicate": str(row.p),
        "object": str(row.o)
    })

# Convert the list to a DataFrame
df_relationships = pd.DataFrame(data)


df_relationships
# Out:
#                                                                               subject  \
# 0                          https://w3id.org/secure-chain/Vulnerability/CVE-2021-38472
# 1                          https://w3id.org/secure-chain/Vulnerability/CVE-2020-10266
# 2                        https://w3id.org/secure-chain/Vulnerability/CVE-2016-1000028
# 3              https://w3id.org/secure-chain/SoftwareVersion/llama.cpp#master-8596af4
# 4                          https://w3id.org/secure-chain/SoftwareVersion/chdb#v0.11.5
# ...                                                                               ...
# 9995                          https://w3id.org/secure-chain/HardwareVersion/qca6391#-
# 9996                       https://w3id.org/secure-chain/SoftwareVersion/slop#v5.3.35
# 9997                       https://w3id.org/secure-chain/SoftwareVersion/vym#2.6.11-3
# 9998                  https://w3id.org/secure-chain/SoftwareVersion/grpc#v1.65.0-pre2
# 9999  https://w3id.org/secure-chain/SoftwareVersion/Cataclysm-DDA#cdda-jenkins-b10888
#
#                                             predicate  \
# 0     https://w3id.org/secure-chain/vulnerabilityType
# 1     https://w3id.org/secure-chain/vulnerabilityType
# 2     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3             https://w3id.org/secure-chain/dependsOn
# 4             https://w3id.org/secure-chain/dependsOn
# ...                                               ...
# 9995       https://w3id.org/secure-chain/vulnerableTo
# 9996          https://w3id.org/secure-chain/dependsOn
# 9997          https://w3id.org/secure-chain/dependsOn
# 9998          https://w3id.org/secure-chain/dependsOn
# 9999          https://w3id.org/secure-chain/dependsOn
#
#                                                                                                     object
# 0                                                 https://w3id.org/secure-chain/VulnerabilityType/CWE-1021
# 1                                                  https://w3id.org/secure-chain/VulnerabilityType/CWE-345
# 2                                                              https://w3id.org/secure-chain/Vulnerability
# 3                                                https://w3id.org/secure-chain/SoftwareVersion/threads#%2A
# 4     https://w3id.org/secure-chain/SoftwareVersion/aws-checksums#ad53be196a25bbefa3700a01187fdce573a7d2d0
# ...                                                                                                    ...
# 9995                                            https://w3id.org/secure-chain/Vulnerability/CVE-2021-30349
# 9996                                                 https://w3id.org/secure-chain/SoftwareVersion/glx#%2A
# 9997                               https://w3id.org/secure-chain/SoftwareVersion/libstdc%2B%2B6#%3E%3D+5.2
# 9998                                      https://w3id.org/secure-chain/SoftwareVersion/debug_location#%2A
# 9999                                                  https://w3id.org/secure-chain/SoftwareVersion/ole#32
#
# [10000 rows x 3 columns]

# %%
df_relationships1 = df_relationships.copy()

# Extract identifiers from subject, predicate, and object URIs
df_relationships1[['subject_type', 'version']] = df_relationships1['subject'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)


df_relationships1['predicate_type'] = df_relationships1['predicate'].apply(lambda x: x.split('/')[-1].split('#')[-1])
# Split 'object' into 'object_type' and 'object_detail'
df_relationships1[['object_type', 'object_detail']] = df_relationships1['object'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)
# Display the updated DataFrame
df_relationships2 = df_relationships1[['subject_type', 'version', 'predicate_type', 'object_type', 'object_detail']]

# %%
df_relationships = pd.DataFrame(data)

df_relationships[['product_type', 'software_version']] = df_relationships['subject'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)
df_relationships[['product', 'version']] = df_relationships['software_version'].str.split('#', expand=True)
df_relationships['predicate_type'] = df_relationships['predicate'].apply(lambda x: x.split('/')[-1].split('#')[-1])
df_relationships[['object_type', 'object_detail']] = df_relationships['object'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)

df_relationships2 = df_relationships[['product_type', 'product', 'version', 'predicate_type', 'object_type', 'object_detail']]

# %%
df_relationships2
# Out:
#          product_type           product              version  \
# 0       Vulnerability    CVE-2021-38472                 None
# 1       Vulnerability    CVE-2020-10266                 None
# 2       Vulnerability  CVE-2016-1000028                 None
# 3     SoftwareVersion         llama.cpp       master-8596af4
# 4     SoftwareVersion              chdb              v0.11.5
# ...               ...               ...                  ...
# 9995  HardwareVersion           qca6391                    -
# 9996  SoftwareVersion              slop              v5.3.35
# 9997  SoftwareVersion               vym             2.6.11-3
# 9998  SoftwareVersion              grpc         v1.65.0-pre2
# 9999  SoftwareVersion     Cataclysm-DDA  cdda-jenkins-b10888
#
#          predicate_type        object_type  \
# 0     vulnerabilityType  VulnerabilityType
# 1     vulnerabilityType  VulnerabilityType
# 2                  type       secure-chain
# 3             dependsOn    SoftwareVersion
# 4             dependsOn    SoftwareVersion
# ...                 ...                ...
# 9995       vulnerableTo      Vulnerability
# 9996          dependsOn    SoftwareVersion
# 9997          dependsOn    SoftwareVersion
# 9998          dependsOn    SoftwareVersion
# 9999          dependsOn    SoftwareVersion
#
#                                                object_detail
# 0                                                   CWE-1021
# 1                                                    CWE-345
# 2                                              Vulnerability
# 3                                                threads#%2A
# 4     aws-checksums#ad53be196a25bbefa3700a01187fdce573a7d2d0
# ...                                                      ...
# 9995                                          CVE-2021-30349
# 9996                                                 glx#%2A
# 9997                               libstdc%2B%2B6#%3E%3D+5.2
# 9998                                      debug_location#%2A
# 9999                                                  ole#32
#
# [10000 rows x 6 columns]

# %%
df_relationships2[df_relationships2['product'] == 'octave']
# Out:
#          product_type product            version predicate_type  \
# 1413  SoftwareVersion  octave   4.4.1-4~bpo9%2B1      dependsOn
# 2081  SoftwareVersion  octave  3.6.2-5~bpo60%2B1      dependsOn
# 3314  SoftwareVersion  octave       9.2.0-2%2Bb1      dependsOn
# 3525  SoftwareVersion  octave   4.0.3-1~bpo8%2B1      dependsOn
# 3999  SoftwareVersion  octave     4.4.1-6ubuntu1      dependsOn
# 7527  SoftwareVersion  octave   4.0.0-3ubuntu9.2      dependsOn
# 7957  SoftwareVersion  octave            7.2.0-1      dependsOn
# 8011  SoftwareVersion  octave            3.8.2-4      dependsOn
# 9263  SoftwareVersion  octave            7.2.0-1      dependsOn
# 9690  SoftwareVersion  octave   3.6.2-5%2Bdeb7u1           type
#
#           object_type                       object_detail
# 1413  SoftwareVersion  libqt5scintilla2-12v5#%3E%3D+2.8.4
# 2081  SoftwareVersion                      libblas3gf#%2A
# 3314  SoftwareVersion       libfltk-gl1.3t64#%3E%3D+1.3.0
# 3525  SoftwareVersion      libqt4-opengl#%3E%3D+4%3A4.5.3
# 3999  SoftwareVersion            libqt5help5#%3E%3D+5.9.0
# 7527  SoftwareVersion             libfltk1.3#%3E%3D+1.3.3
# 7957  SoftwareVersion    libqt5printsupport5#%3E%3D+5.0.2
# 8011  SoftwareVersion                libfftw3-single3#%2A
# 9263  SoftwareVersion               libgfortran5#%3E%3D+8
# 9690     secure-chain                     SoftwareVersion

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

class SBOMService:
    def __init__(self, endpoint_url):
        self.endpoint_url = endpoint_url
        self.sparql_client = SPARQLWrapper(endpoint_url)

    def get_vulnerabilities(self, software_name, software_version):
        vulnerabilities_query = f"""
        PREFIX sc: <https://w3id.org/secure-chain/>
        PREFIX schema: <http://schema.org/>

        SELECT ?vulnerability
        WHERE {{
            # ?software a sc:Software .
            # ?software schema:name "{software_name}" .
            # ?software sc:hasSoftwareVersion ?softwareVersion .
            # ?softwareVersion sc:versionName "{software_version}" .
            # ?softwareVersion sc:vulnerableTo ?vulnerability .
        }}
        """
        self.sparql_client.setQuery(vulnerabilities_query)
        self.sparql_client.setReturnFormat(JSON)
        results = self.sparql_client.query().convert()

        vulnerabilities = [result['vulnerability']['value'] for result in results["results"]["bindings"]]
        return vulnerabilities

# Create an instance of SBOMService with your endpoint
sbom_service = SBOMService('http://your-sparql-endpoint.com')

# Example usage
software_name = "ExampleSoftware"
software_version = "1.0.0"
vulnerabilities = sbom_service.get_vulnerabilities(software_name, software_version)
print(vulnerabilities)

# %%
###### FUTURE WORK ########################################################################################################################

# %%
# Enrich dependencies with their class>> returns nan clases not working
#df_properties = df_properties.merge(df_classes, left_on='dependency', right_on='class', how='left')
#df_properties.rename(columns={'class_name': 'dependency_class'}, inplace=True)

#print(df_properties.head(100))

# %%
query_dependencies = """
PREFIX sc: <https://w3id.org/secure-chain/>
SELECT ?software ?dependency
WHERE {
    # ?software sc:dependsOn ?dependency .
}
LIMIT 100000
"""

#for row in g.query(query_dependencies):
    #print(f"Software: {row.software}, Dependency: {row.dependency}")

# Execute the query
results = g.query(query_dependencies)
# Create a list of dictionaries, one for each record
data = []
for row in results:
    data.append({
        "software": str(row.software),
        "dependency": str(row.dependency)
    })

# Convert the list to a DataFrame
df_dependencies = pd.DataFrame(data)
print(df.head())
# Out:
#                                                                 software  \
# 0  https://w3id.org/secure-chain/SoftwareVersion/proxygen#v2021.05.03.00
# 1     https://w3id.org/secure-chain/SoftwareVersion/folly#v2020.09.28.00
# 2  https://w3id.org/secure-chain/SoftwareVersion/fbthrift#v2023.07.31.00
# 3  https://w3id.org/secure-chain/SoftwareVersion/proxygen#v2021.07.12.00
# 4  https://w3id.org/secure-chain/SoftwareVersion/proxygen#v2020.02.03.00
#
#                                                dependency
# 0  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 1  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 2  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 3  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 4  https://w3id.org/secure-chain/SoftwareVersion/python#3

# %%
df_dependencies
# Out:
#                                                                            software  \
# 0             https://w3id.org/secure-chain/SoftwareVersion/proxygen#v2021.05.03.00
# 1                https://w3id.org/secure-chain/SoftwareVersion/folly#v2020.09.28.00
# 2             https://w3id.org/secure-chain/SoftwareVersion/fbthrift#v2023.07.31.00
# 3             https://w3id.org/secure-chain/SoftwareVersion/proxygen#v2021.07.12.00
# 4             https://w3id.org/secure-chain/SoftwareVersion/proxygen#v2020.02.03.00
# ...                                                                             ...
# 99995        https://w3id.org/secure-chain/SoftwareVersion/r-cran-fs#1.6.1%2Bdfsg-1
# 99996          https://w3id.org/secure-chain/SoftwareVersion/shairport-sync#3.3.8-1
# 99997      https://w3id.org/secure-chain/SoftwareVersion/zita-ajbridge#0.8.4-1%2Bb1
# 99998  https://w3id.org/secure-chain/SoftwareVersion/ruby-kyotocabinet#1.34-2build1
# 99999                    https://w3id.org/secure-chain/SoftwareVersion/kraft#0.98-1
#
#                                                                dependency
# 0                  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 1                  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 2                  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 3                  https://w3id.org/secure-chain/SoftwareVersion/python#3
# 4                  https://w3id.org/secure-chain/SoftwareVersion/python#3
# ...                                                                   ...
# 99995  https://w3id.org/secure-chain/SoftwareVersion/libgcc-s1#%3E%3D+3.0
# 99996  https://w3id.org/secure-chain/SoftwareVersion/libgcc-s1#%3E%3D+3.0
# 99997  https://w3id.org/secure-chain/SoftwareVersion/libgcc-s1#%3E%3D+3.0
# 99998  https://w3id.org/secure-chain/SoftwareVersion/libgcc-s1#%3E%3D+3.0
# 99999  https://w3id.org/secure-chain/SoftwareVersion/libgcc-s1#%3E%3D+3.0
#
# [100000 rows x 2 columns]

# %%
df_dependencies[['product_type', 'software_version']] = df_dependencies['software'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)
df_dependencies[['product', 'version']] = df_dependencies['software_version'].str.split('#', expand=True)
#df_dependencies['dependency_type'] = df_dependencies['dependency'].apply(lambda x: x.split('/')[-1].split('#')[-1])
df_dependencies[['dependency_type', 'dependency_detail']] = df_dependencies['dependency'].apply(
    lambda x: pd.Series(x.split('/')[-2:])
)

df_dependencies2 = df_dependencies[['product_type', 'product', 'version', 'dependency_type','dependency_detail']]

# %%
df_dependencies2[df_dependencies2['product'] == 'octave']
# Out:
#           product_type product                version  dependency_type  \
# 5228   SoftwareVersion  octave       4.0.3-1~bpo8%2B1  SoftwareVersion
# 5571   SoftwareVersion  octave                3.8.2-4  SoftwareVersion
# 5896   SoftwareVersion  octave                4.0.3-3  SoftwareVersion
# 6178   SoftwareVersion  octave       3.6.2-5%2Bdeb7u1  SoftwareVersion
# 6242   SoftwareVersion  octave       4.0.0-3ubuntu9.2  SoftwareVersion
# ...                ...     ...                    ...              ...
# 85281  SoftwareVersion  octave          9.2.0-2build1  SoftwareVersion
# 85321  SoftwareVersion  octave           9.2.0-2%2Bb1  SoftwareVersion
# 95211  SoftwareVersion  octave          5.2.0-3build1  SoftwareVersion
# 95295  SoftwareVersion  octave                5.2.0-1  SoftwareVersion
# 98307  SoftwareVersion  octave  6.1.1~hg.2021.01.26-1  SoftwareVersion
#
#                dependency_detail
# 5228   libstdc%2B%2B6#%3E%3D+4.9
# 5571   libstdc%2B%2B6#%3E%3D+4.9
# 5896         libgl1-mesa-glx#%2A
# 6178         libgl1-mesa-glx#%2A
# 6242         libgl1-mesa-glx#%2A
# ...                          ...
# 85281     libgcc-s1#%3E%3D+3.3.1
# 85321     libgcc-s1#%3E%3D+3.3.1
# 95211       libgcc-s1#%3E%3D+3.0
# 95295       libgcc-s1#%3E%3D+3.0
# 98307       libgcc-s1#%3E%3D+3.0
#
# [71 rows x 5 columns]

# %%
from rdflib import Graph, Namespace
from rdflib.plugins.stores.sparqlstore import SPARQLStore
SPARQL_ENDPOINT_URL = 'http://localhost:3030/kg/query'
SPARQL_UPDATE_ENDPOINT_URL = 'http://localhost:3030/kg/update'


# Set up namespaces
SC = Namespace("https://w3id.org/secure-chain/")
SCHEMA = Namespace("http://schema.org/")

# Set up the SPARQL endpoint
sparql_endpoint = 'http://localhost:3030/kg/query'
store = SPARQLStore(sparql_endpoint)
g = Graph(store=store)

def get_dependencies(software_name, software_version):
    query = f"""
    PREFIX sc: <https://w3id.org/secure-chain/>
    PREFIX schema: <http://schema.org/>

    SELECT ?dependency 
    WHERE {{
        # ?software a sc:Software .
        # ?software schema:name "{software_name}" .
        # ?software sc:hasSoftwareVersion ?softwareVersion .
        # ?softwareVersion sc:versionName "{software_version}" .
        # ?softwareVersion sc:dependsOn ?dependency .
    }}
    """
    print("Querying dependencies for:", software_name, "version", software_version)
    results = g.query(query)
    dependencies = [str(binding['dependency']) for binding in results]
    print("Dependencies found:", dependencies)
    return dependencies

# %%
dependencies = get_dependencies("octave", "4.0.3-1~bpo8+1")
print(dependencies)
# Out:
# Querying dependencies for: octave version 4.0.3-1~bpo8+1
# Dependencies found: ['https://w3id.org/secure-chain/SoftwareVersion/libstdc%2B%2B6#%3E%3D+4.9', 'https://w3id.org/secure-chain/SoftwareVersion/libgl1-mesa-glx#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libfreetype6#%3E%3D+2.2.1', 'https://w3id.org/secure-chain/SoftwareVersion/libx11-6#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libblas.so.3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqtgui4#%3E%3D+4%3A4.8.0', 'https://w3id.org/secure-chain/SoftwareVersion/libgcc1#%3E%3D+1%3A4.1.1', 'https://w3id.org/secure-chain/SoftwareVersion/liblapack.so.3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libblas3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libgl1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libglu1-mesa#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqtcore4#%3E%3D+4%3A4.7.0~beta1', 'https://w3id.org/secure-chain/SoftwareVersion/liblapack3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqt4-network#%3E%3D+4%3A4.5.3', 'https://w3id.org/secure-chain/SoftwareVersion/libgomp1#%3E%3D+4.2.1', 'https://w3id.org/secure-chain/SoftwareVersion/libglu1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libasound2#%3E%3D+1.0.16', 'https://w3id.org/secure-chain/SoftwareVersion/libfltk1.3#%3E%3D+1.3.1', 'https://w3id.org/secure-chain/SoftwareVersion/libsndfile1#%3E%3D+1.0.20', 'https://w3id.org/secure-chain/SoftwareVersion/libc6#%3E%3D+2.11', 'https://w3id.org/secure-chain/SoftwareVersion/libqt4-opengl#%3E%3D+4%3A4.5.3', 'https://w3id.org/secure-chain/SoftwareVersion/libportaudio2#%3E%3D+19%2Bsvn20101113', 'https://w3id.org/secure-chain/SoftwareVersion/libarpack2#%3E%3D+2.1', 'https://w3id.org/secure-chain/SoftwareVersion/libfontconfig1#%3E%3D+2.11', 'https://w3id.org/secure-chain/SoftwareVersion/libfltk-gl1.3#%3E%3D+1.3.0', 'https://w3id.org/secure-chain/SoftwareVersion/texinfo#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libfftw3-double3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libfftw3-single3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libosmesa6#%3E%3D+10.2~', 'https://w3id.org/secure-chain/SoftwareVersion/libqscintilla2-11#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqrupdate1#%3E%3D+1.0', 'https://w3id.org/secure-chain/SoftwareVersion/libumfpack5.6.2#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libccolamd2.8.0#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/liboctave3#4.0.3-1~bpo8%2B1', 'https://w3id.org/secure-chain/SoftwareVersion/libamd2.3.1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqhull6#%3E%3D+2012.1', 'https://w3id.org/secure-chain/SoftwareVersion/libcholmod2.1.2#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libglpk36#%3E%3D+4.51', 'https://w3id.org/secure-chain/SoftwareVersion/libcolamd2.8.0#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libcxsparse3.1.2#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libcamd2.3.1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/octave-common#4.0.3-1~bpo8%2B1']
# ['https://w3id.org/secure-chain/SoftwareVersion/libstdc%2B%2B6#%3E%3D+4.9', 'https://w3id.org/secure-chain/SoftwareVersion/libgl1-mesa-glx#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libfreetype6#%3E%3D+2.2.1', 'https://w3id.org/secure-chain/SoftwareVersion/libx11-6#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libblas.so.3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqtgui4#%3E%3D+4%3A4.8.0', 'https://w3id.org/secure-chain/SoftwareVersion/libgcc1#%3E%3D+1%3A4.1.1', 'https://w3id.org/secure-chain/SoftwareVersion/liblapack.so.3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libblas3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libgl1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libglu1-mesa#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqtcore4#%3E%3D+4%3A4.7.0~beta1', 'https://w3id.org/secure-chain/SoftwareVersion/liblapack3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqt4-network#%3E%3D+4%3A4.5.3', 'https://w3id.org/secure-chain/SoftwareVersion/libgomp1#%3E%3D+4.2.1', 'https://w3id.org/secure-chain/SoftwareVersion/libglu1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libasound2#%3E%3D+1.0.16', 'https://w3id.org/secure-chain/SoftwareVersion/libfltk1.3#%3E%3D+1.3.1', 'https://w3id.org/secure-chain/SoftwareVersion/libsndfile1#%3E%3D+1.0.20', 'https://w3id.org/secure-chain/SoftwareVersion/libc6#%3E%3D+2.11', 'https://w3id.org/secure-chain/SoftwareVersion/libqt4-opengl#%3E%3D+4%3A4.5.3', 'https://w3id.org/secure-chain/SoftwareVersion/libportaudio2#%3E%3D+19%2Bsvn20101113', 'https://w3id.org/secure-chain/SoftwareVersion/libarpack2#%3E%3D+2.1', 'https://w3id.org/secure-chain/SoftwareVersion/libfontconfig1#%3E%3D+2.11', 'https://w3id.org/secure-chain/SoftwareVersion/libfltk-gl1.3#%3E%3D+1.3.0', 'https://w3id.org/secure-chain/SoftwareVersion/texinfo#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libfftw3-double3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libfftw3-single3#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libosmesa6#%3E%3D+10.2~', 'https://w3id.org/secure-chain/SoftwareVersion/libqscintilla2-11#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqrupdate1#%3E%3D+1.0', 'https://w3id.org/secure-chain/SoftwareVersion/libumfpack5.6.2#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libccolamd2.8.0#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/liboctave3#4.0.3-1~bpo8%2B1', 'https://w3id.org/secure-chain/SoftwareVersion/libamd2.3.1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libqhull6#%3E%3D+2012.1', 'https://w3id.org/secure-chain/SoftwareVersion/libcholmod2.1.2#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libglpk36#%3E%3D+4.51', 'https://w3id.org/secure-chain/SoftwareVersion/libcolamd2.8.0#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libcxsparse3.1.2#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/libcamd2.3.1#%2A', 'https://w3id.org/secure-chain/SoftwareVersion/octave-common#4.0.3-1~bpo8%2B1']

# %%
query_classes = """
SELECT DISTINCT ?class
WHERE {
    # ?s a ?class .
}
"""
for row in g.query(query_classes):
    print(row)

results = g.query(query_classes)

# Collect data into a list of dictionaries
data = []
for row in results:
    # Correctly access the variable ?class from the result row
    class_uri = str(row['class'])  # Use the variable name as the key in the row dictionary
    data.append({"class": class_uri})

# Convert the list to a DataFrame
df_classes = pd.DataFrame(data)
# Extract local names from the URIs
df_classes['class_name'] = df_classes['class'].apply(lambda x: x.split('#')[-1] if '#' in x else x.split('/')[-1])
df_classes['prefix'] = df_classes['class'].apply(lambda x: x.split('#')[0] if '#' in x else '/'.join(x.split('/')[:-1]))

# Display the updated DataFrame
print(df_classes.head())

# %%
data = []

# Collect namespace information into a list of dictionaries
for prefix, namespace in g.namespaces():
    data.append({
        "prefix": str(prefix),
        "namespace": str(namespace)
    })

# Convert the list to a DataFrame
df_namespaces = pd.DataFrame(data)
print(df_namespaces.head())
